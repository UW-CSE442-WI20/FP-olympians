# %%
import pandas as pd
import numpy as np
import re

regex = re.compile('[^a-zA-Z ]')

# %%
olympics = pd.read_csv('athlete_events.csv')

# %%
olympics.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
olympics.shape
# Out:
# (271116, 15)

# %%
recent = olympics[olympics['Year'] >= 1980]

recent.shape
# Out:
# (157417, 15)

# %%
final = recent[recent['Season'] == 'Summer']

final.shape
# Out:
# (122913, 15)

# %%
final
# Out:
#             ID                          Name Sex   Age  Height  Weight  \
# 0            1                     A Dijiang   M  24.0   180.0    80.0
# 1            2                      A Lamusi   M  23.0   170.0    60.0
# 31          12             Jyri Tapani Aalto   M  31.0   172.0    70.0
# 32          13            Minna Maarit Aalto   F  30.0   159.0    55.5
# 33          13            Minna Maarit Aalto   F  34.0   159.0    55.5
# ...        ...                           ...  ..   ...     ...     ...
# 271105  135565      Fernando scar Zylberberg   M  23.0   168.0    76.0
# 271106  135565      Fernando scar Zylberberg   M  27.0   168.0    76.0
# 271108  135567  Aleksandr Viktorovich Zyuzin   M  24.0   183.0    72.0
# 271109  135567  Aleksandr Viktorovich Zyuzin   M  28.0   183.0    72.0
# 271110  135568        Olga Igorevna Zyuzkova   F  33.0   171.0    69.0
#
#              Team  NOC        Games  Year  Season            City       Sport  \
# ...

# %%
temp = final[final['Team'].str.contains("/")]
temp
# Out:
# Empty DataFrame
# Columns: [ID, Name, Sex, Age, Height, Weight, Team, NOC, Games, Year, Season, City, Sport, Event, Medal]
# Index: []

# %%
print(final[final['Team'] == 'Switzerland-1'])
# Out:
#             ID                       Name Sex   Age  Height  Weight  \
# 40034    20589  Sbastien "Sba" Chevallier   M  25.0   193.0    88.0
# 93219    47200             Joana Heidrich   F  24.0   190.0    72.0
# 95523    48364               Sascha Heyer   M  40.0   203.0   108.0
# 130559   65733              Martin Laciga   M  29.0   195.0   100.0
# 130560   65733              Martin Laciga   M  33.0   195.0   100.0
# 130562   65734                Paul Laciga   M  33.0   193.0    92.0
# 213699  107314               Jan Schnider   M  25.0   197.0    95.0
# 270791  135424             Nadine Zumkehr   F  31.0   172.0    64.0
#
#                  Team  NOC        Games  Year  Season            City  \
# 40034   Switzerland-1  SUI  2012 Summer  2012  Summer          London
# 93219   Switzerland-1  SUI  2016 Summer  2016  Summer  Rio de Janeiro
# 95523   Switzerland-1  SUI  2012 Summer  2012  Summer          London
# 130559  Switzerland-1  SUI  2004 Summer  2004  Summer          Athina
# ...

# %%
final['Team'] = final['Team'].apply(lambda x: re.sub(regex, '', str(x)))
# Out:
# /Users/Millicent/miniconda3/envs/cse442/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
print(final[final['Team'] == 'Switzerland-1'])
# Out:
# Empty DataFrame
# Columns: [ID, Name, Sex, Age, Height, Weight, Team, NOC, Games, Year, Season, City, Sport, Event, Medal]
# Index: []

# %%
print(final[final['Team'] == 'Australia-1'])
# Out:
# Empty DataFrame
# Columns: [ID, Name, Sex, Age, Height, Weight, Team, NOC, Games, Year, Season, City, Sport, Event, Medal]
# Index: []

# %%
final = final.copy()
final['Team'] = final['Team'].replace(['Lancet'], 'Great Britain')
final = final.copy()
final['Team'] = final['Team'].replace(['Bonaparte'], 'Germany')
final = final.copy()
final['Team'] = final['Team'].replace(['Brentina'], 'United States')
final = final.copy()
final['Team'] = final['Team'].replace(['Briar'], 'Sweden')
final = final.copy()
final['Team'] = final['Team'].replace(['Calimucho'], 'France')
final = final.copy()
final['Team'] = final['Team'].replace(['Clearwater'], 'Denmark')
final = final.copy()
final['Team'] = final['Team'].replace(['Diabolo St Maurice'], 'France')
final = final.copy()
final['Team'] = final['Team'].replace(['Digby'], 'Denmark')
final = final.copy()
final['Team'] = final['Team'].replace(['Don Schufro'], 'Denmark')
final = final.copy()
final['Team'] = final['Team'].replace(['Dow Jones'], 'Japan')
final = final.copy()
final['Team'] = final['Team'].replace(['Elvis Va'], 'Germany')
final = final.copy()
final['Team'] = final['Team'].replace(['Floresco'], 'Sweden')
final = final.copy()
final['Team'] = final['Team'].replace(['Galopin De La Font'], 'Portugal')
final = final.copy()
final['Team'] = final['Team'].replace(['Gran Gesto'], 'Canada')
final = final.copy()
final['Team'] = final['Team'].replace(['Greenoaks Dundee'], 'Australia')
final = final.copy()
final['Team'] = final['Team'].replace(['Lucky Star'], 'Great Britain')
final = final.copy()
final['Team'] = final['Team'].replace(['Mistral Hojris'], 'Great Britain')
final = final.copy()
final['Team'] = final['Team'].replace(['Mythilus'], 'United States')
final = final.copy()
final['Team'] = final['Team'].replace(['Nadine'], 'Netherlands')
final = final.copy()
final['Team'] = final['Team'].replace(['Notavel'], 'Portugal')
final = final.copy()
final['Team'] = final['Team'].replace(['Orion'], 'Canada')
final = final.copy()
final['Team'] = final['Team'].replace(['Oxalis'], 'Portugal')
final = final.copy()
final['Team'] = final['Team'].replace(['Pop Art'], 'Canada')
final = final.copy()
final['Team'] = final['Team'].replace(['Quando Quando'], 'Australia')
final = final.copy()
final['Team'] = final['Team'].replace(['Rambo'], 'Japan')
final = final.copy()
final['Team'] = final['Team'].replace(['Ravel'], 'United States')
final = final.copy()
final['Team'] = final['Team'].replace(['Relampago'], 'Australia')
final = final.copy()
final['Team'] = final['Team'].replace(['Salinero'], 'Netherlands')
final = final.copy()
final['Team'] = final['Team'].replace(['Satchmo'], 'Germany')
final = final.copy()
final['Team'] = final['Team'].replace(['Solos Carex'], 'Sweden')
final = final.copy()
final['Team'] = final['Team'].replace(['Sunrise'], 'Netherlands')
final = final.copy()
final['Team'] = final['Team'].replace(['Whisper'], 'Japan')
final = final.copy()
final['Team'] = final['Team'].replace(['Whitini Star'], 'France')

# %%
print(final[final['Team'] == 'Lancet'])
print(final[final['Team'] == 'Bonaparte'])
# Out:
# Empty DataFrame
# Columns: [ID, Name, Sex, Age, Height, Weight, Team, NOC, Games, Year, Season, City, Sport, Event, Medal, Lancet, 0]
# Index: []
# Empty DataFrame
# Columns: [ID, Name, Sex, Age, Height, Weight, Team, NOC, Games, Year, Season, City, Sport, Event, Medal, Lancet, 0]
# Index: []

# %%
export_csv = final.to_csv (r'olympics.csv', index = None, header=True)
